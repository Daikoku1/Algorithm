# %%
# 29200	KB, 68 ms
N = int(input())
arr = list(map(int, input().split()))

ans = [0] * N
for i, v1 in enumerate(arr[:-1]):
    pre_g = float('-inf')
    for j, v2 in enumerate(arr[i+1:], i+1):
        if (v2 - v1) / (j-i) <= pre_g : continue
        pre_h = v2
        pre_g = (v2-v1) / (j-i)
        ans[i] += 1
        ans[j] += 1

print(max(ans))
# Out:
# -----------------
# 0 1
# 5 4.0
# pre_g 0 2
# pre_g 0 3
# pre_g 0 4
# pre_g 0 5
# pre_g 0 6
# pre_g 0 7
# pre_g 0 8
# pre_g 0 9
# pre_g 0 10
# pre_g 0 11
# pre_g 0 12
# pre_g 0 13
# pre_g 0 14
# -----------------
# 1 2
# 3 -2.0
# -----------------
# 1 3
# 2 -1.5
# -----------------
# 1 4
# 6 0.3333333333333333
# pre_g 1 5
# pre_g 1 6
# pre_g 1 7
# pre_g 1 8
# pre_g 1 9
# pre_g 1 10
# pre_g 1 11
# pre_g 1 12
# pre_g 1 13
# pre_g 1 14
# -----------------
# 2 3
# 2 -1.0
# -----------------
# 2 4
# 6 1.5
# pre_g 2 5
# pre_g 2 6
# pre_g 2 7
# pre_g 2 8
# pre_g 2 9
# pre_g 2 10
# pre_g 2 11
# pre_g 2 12
# pre_g 2 13
# pre_g 2 14
# -----------------
# 3 4
# 6 4.0
# pre_g 3 5
# pre_g 3 6
# pre_g 3 7
# pre_g 3 8
# pre_g 3 9
# pre_g 3 10
# pre_g 3 11
# pre_g 3 12
# pre_g 3 13
# pre_g 3 14
# -----------------
# 4 5
# 3 -3.0
# -----------------
# 4 6
# 2 -2.0
# -----------------
# 4 7
# 6 0.0
# pre_g 4 8
# pre_g 4 9
# pre_g 4 10
# -----------------
# 4 11
# 7 0.14285714285714285
# pre_g 4 12
# ...
